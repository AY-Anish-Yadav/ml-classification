# %%
# Preprocessing Plan:
# Step 1: Drop useless columns (ID, Name, SSN)
# Step 2: Clean dirty values (/, -, NM, !@9#%8)
# Step 3: Convert str columns to numeric (Age, Annual_Income etc.)
# Step 4: Cap outliers (IQR method)
# Step 5: Impute nulls (median for numeric, mode for categorical)
# Step 6: Encode categorical features
# Step 7: Encode target (Good=0, Standard=1, Poor=2)
# Step 8: Train/Val/Test split (stratified)
# Step 9: Scale numeric features
# Step 10: Save processed

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import warnings
warnings.filterwarnings('ignore')

print("✅ Imports successful!")
